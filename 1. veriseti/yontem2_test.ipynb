# %% [markdown]
# ## 1. Kütüphane İmportları ve Konfigürasyon
#
# Bu bölüm, training notebook'unda kullanılan tüm sınıfları ve kaydedilen model bileşenlerini yükler.

# %%
import pandas as pd
import numpy as np
import os
import sys
import pickle
import re
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences

print("Kütüphaneler başarıyla yüklendi!")
print(f"Çalışma dizini: {os.getcwd()}")
print(f"Python versiyonu: {sys.version.split()[0]}")
# Out:
# Kütüphaneler başarıyla yüklendi!
# Çalışma dizini: c:\Users\alper\OneDrive\Masaüstü\dersler\yap470\topic_calssifier\1. veriseti
# Python versiyonu: 3.11.9

# %% [markdown]
# ## 3. Bileşenleri Yükle ve CSV Test Verileri Hazırla

# %%
# ============================================================================
# YÖNTEM 2 (RNN) MODELİNİ YÜKLE VE TEST ET
# ============================================================================

print("Sistem kontrolleri...")
print(f"Çalışma dizini: {os.getcwd()}")
print(f"Python versiyonu: {sys.version.split()[0]}")

# Gerekli dosyalar: models2 klasörü
models2_dir = "models2"
if not os.path.exists(models2_dir):
    print(f"models2 klasörü bulunamadı!")
    print("Çözüm: yontem_2.ipynb notebook'unu çalıştırın!")
    sys.exit()

# Tokenizer ve Config Yükle
with open(os.path.join(models2_dir, "tokenizer_rnn.pkl"), "rb") as f:
    tokenizer = pickle.load(f)
with open(os.path.join(models2_dir, "rnn_model_config.pkl"), "rb") as f:
    model_config = pickle.load(f)

# Modeli Yükle
rnn_model = tf.keras.models.load_model(os.path.join(models2_dir, "rnn_model_final.h5"))

# Test Verisini Hazırla
test_file_path = "archive/test.csv"
test_df = pd.read_csv(test_file_path, header=None)
test_df.columns = ["label", "title", "description"]
test_df = test_df[test_df["label"] != "Class Index"]
test_df = test_df[test_df["label"] != "label"]
test_df = test_df[pd.to_numeric(test_df["label"], errors='coerce').notna()]
test_df["label"] = test_df["label"].astype(int) -1
test_df["combined_text"] = test_df["title"].fillna("") + " " + test_df["description"].fillna("")

def clean_text(text):
    if pd.isna(text):
        return ""
    text = str(text).lower()
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

test_df["cleaned_text"] = test_df["combined_text"].apply(clean_text)
test_df = test_df[test_df["cleaned_text"].str.len() > 0]

# Tokenize ve Pad
sequences = tokenizer.texts_to_sequences(test_df["cleaned_text"])
X_test = pad_sequences(sequences, maxlen=model_config["max_sequence_length"], padding='post', truncating='post')
y_test = test_df["label"].values

# Tahmin ve Değerlendirme
print("Model test verisi üzerinde tahmin yapıyor...")
y_pred_proba = rnn_model.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred_proba, axis=1)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Analiz ve manuel test için gerekli değişkenler
test_texts = test_df["cleaned_text"].tolist()
test_labels = y_test.tolist()

# ============================================================================
# RASTGELE TAHMİNLERİ GÖSTER
# ============================================================================

num_samples = 100  

print(f"\n{'='*80}")
print(f"RASTGELE {num_samples} TAHMİN ÖRNEĞİ")
print(f"{'='*80}")

# Rastgele indeksler seç
np.random.seed(42)  # Tekrarlanabilir sonuçlar için
random_indices = np.random.choice(len(test_texts), size=min(num_samples, len(test_texts)), replace=False)

class_names = {
    0: "World News",
    1: "Sports", 
    2: "Business",
    3: "Science/Technology"
}

correct_predictions = 0
total_predictions = 0

for i, idx in enumerate(random_indices):
    actual_label = test_labels[idx]
    predicted_label = y_pred[idx]
    confidence = y_pred_proba[idx][predicted_label] * 100
    text_sample = test_texts[idx]
    
    # Doğru tahmin mi?
    is_correct = "✓" if actual_label == predicted_label else "✗"
    if actual_label == predicted_label:
        correct_predictions += 1
    total_predictions += 1
    
    print(f"\n{i+1:2d}. Örnek {is_correct}")
    print(f"    Metin: {text_sample[:100]}{'...' if len(text_sample) > 100 else ''}")
    print(f"    Gerçek: {class_names.get(actual_label, actual_label)} ({actual_label})")
    print(f"    Tahmin: {class_names.get(predicted_label, predicted_label)} ({predicted_label})")
    print(f"    Güven: %{confidence:.1f}")
    print("-" * 60)

# Rastgele örneklerdeki accuracy
sample_accuracy = correct_predictions / total_predictions * 100
print(f"\nRastgele {num_samples} örnekteki doğruluk: %{sample_accuracy:.1f} ({correct_predictions}/{total_predictions})")
# Out:
# Sistem kontrolleri...
# Çalışma dizini: c:\Users\alper\OneDrive\Masaüstü\dersler\yap470\topic_calssifier\1. veriseti
# Python versiyonu: 3.11.9
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model test verisi üzerinde tahmin yapıyor...
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Accuracy: 0.9286842105263158
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      1900
#            1       0.97      0.98      0.98      1900
#            2       0.90      0.89      0.90      1900
#            3       0.89      0.92      0.91      1900
#
#     accuracy                           0.93      7600
#    macro avg       0.93      0.93      0.93      7600
# weighted avg       0.93      0.93      0.93      7600
#
#
# Confusion Matrix:
#  [[1742   37   67   54]
#  [  14 1864   13    9]
#  [  40   12 1700  148]
#  [  35    9  104 1752]]
#
# ================================================================================
# RASTGELE 100 TAHMİN ÖRNEĞİ
# ================================================================================
#
#  1. Örnek ✓
#     Metin: fan v fan manchester citytottenham hotspur this weekend manchester city entertain spurs and with las...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %99.8
# ------------------------------------------------------------
#
#  2. Örnek ✗
#     Metin: paris tourists search for key to da vinci code reuters reuters a funny thing happened on the way to ...
#     Gerçek: World News (0)
#     Tahmin: Science/Technology (3)
#     Güven: %99.8
# ------------------------------------------------------------
#
#  3. Örnek ✓
#     Metin: net firms dont tax voip the spanishamerican war is over and a temporary tax created to pay for it sh...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %99.1
# ------------------------------------------------------------
#
#  4. Örnek ✓
#     Metin: dependent species risk extinction the global extinction crisis is worse than thought because thousan...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %97.3
# ------------------------------------------------------------
#
#  5. Örnek ✓
#     Metin: eds is charter member of siebel bpo alliance newsfactor newsfactor siebel systems nasdaq sebl has na...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %100.0
# ------------------------------------------------------------
#
#  6. Örnek ✓
#     Metin: campbell 9 pct profit 39hmmm hmmm good 39 campbell soup co cpbn quote profile research on monday pos...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %100.0
# ------------------------------------------------------------
#
#  7. Örnek ✓
#     Metin: forgoing stiff upper lip charles jousts with critics london in an unusual departure from the traditi...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %99.8
# ------------------------------------------------------------
#
#  8. Örnek ✓
#     Metin: profit plunges at international game tech international game technology the world 39s biggest maker ...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %81.5
# ------------------------------------------------------------
#
#  9. Örnek ✓
#     Metin: salvaging genesis despite a seemingly calamitous crash to earth last month by the genesis spacecraft...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 10. Örnek ✗
#     Metin: chavez rejects cd as opposition venezuela 39s president hugo chavez has announced that he will no lo...
#     Gerçek: Business (2)
#     Tahmin: World News (0)
#     Güven: %89.0
# ------------------------------------------------------------
#
# 11. Örnek ✓
#     Metin: ncaa wrong to close book on williams topranked and defending conational champion usc opens its seaso...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 12. Örnek ✓
#     Metin: general mills goes whole grains new york cnnmoney general mills announced plans thursday to start us...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 13. Örnek ✓
#     Metin: big merger could box qwest in qwest communications may not be immediately affected by a sprintnextel...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %98.6
# ------------------------------------------------------------
#
# 14. Örnek ✓
#     Metin: ukrainian opposition makes gains kiev the ukrainian parliament voted yesterday to dismiss the govern...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 15. Örnek ✓
#     Metin: united apology over website abuse manchester united have been forced to issue an embarrassing apolog...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %98.3
# ------------------------------------------------------------
#
# 16. Örnek ✓
#     Metin: davis cup australia takes 20 lead in world group playoff lleyton hewitt gave australia a 20 lead in ...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 17. Örnek ✓
#     Metin: mortgage approvals drop sharply figures showing falling mortgage approvals and rising repossessions ...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %99.8
# ------------------------------------------------------------
#
# 18. Örnek ✓
#     Metin: game day recap thursday september 09 bobby madritsch pitched eight shutout innings and the seattle m...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 19. Örnek ✓
#     Metin: clouds darken peoplesoft conference san francisco peoplesoft inc is trying to create a partylike atm...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %88.9
# ------------------------------------------------------------
#
# 20. Örnek ✓
#     Metin: giants give up right to void bonds deal ap ap barry bonds will have two more seasons to break hank a...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 21. Örnek ✓
#     Metin: linux groups patch image flaw com december 8 2004 248 pm pt several flaws in common linux code used ...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 22. Örnek ✓
#     Metin: this year 39s panthers could learn a thing or two from michael vick charlotte michael vick headbutti...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 23. Örnek ✓
#     Metin: japanese prime minister inspects four northern islands under ltbgtltbgt on september 2 japanese prim...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 24. Örnek ✓
#     Metin: palestinians kill three israeli soldiers palestinian fighters sneaked onto an israeli military post ...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 25. Örnek ✓
#     Metin: premiership charlton snatch win dennis rommedahl grabbed an injurytime winner for charlton against a...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %98.8
# ------------------------------------------------------------
#
# 26. Örnek ✓
#     Metin: baseballred sox on brink of world series victory st louis reuters pedro martinez pitched seven shuto...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 27. Örnek ✓
#     Metin: prince charles chastised for quotold fashioned quot views a minister has launched a scathing attack ...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %99.3
# ------------------------------------------------------------
#
# 28. Örnek ✓
#     Metin: old bones unearth new date for giant deer 39s last stand a new investigation into extinctions caused...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 29. Örnek ✓
#     Metin: different time different team with 325 left in the third quarter the score was 330 and the 79406 fan...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 30. Örnek ✓
#     Metin: oracle quarterly net income rises 16 pct oracle corp orclo quote profile research on tuesday reporte...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 31. Örnek ✓
#     Metin: tributes flood in for nicholson former tottenham captain dave mackay has led the tributes to legenda...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %93.8
# ------------------------------------------------------------
#
# 32. Örnek ✓
#     Metin: eu chief battles to avert veto in crunch vote afp afp the european union braced for a knifeedge vote...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %95.4
# ------------------------------------------------------------
#
# 33. Örnek ✓
#     Metin: gateway updates 4q year guidance gateway inc on wednesday raised fourthquarter earnings expectations...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %90.6
# ------------------------------------------------------------
#
# 34. Örnek ✓
#     Metin: computer associates exec pleads not guilty sanjay kumar the former chief executive of computer assoc...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %89.0
# ------------------------------------------------------------
#
# 35. Örnek ✓
#     Metin: sales boost for house of fraser shares in uk department store group house of fraser have risen after...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %99.8
# ------------------------------------------------------------
#
# 36. Örnek ✗
#     Metin: selling houston warts and all especially warts descriptions of urban afflictions and images of giant...
#     Gerçek: Business (2)
#     Tahmin: Science/Technology (3)
#     Güven: %70.1
# ------------------------------------------------------------
#
# 37. Örnek ✓
#     Metin: fannie mae mess worries investors the fallout from allegations of serious accounting problems at fan...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %99.8
# ------------------------------------------------------------
#
# 38. Örnek ✓
#     Metin: strongwoman hoists 100th gold for chinese delegation tang gonghong lifted a world record to claim in...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 39. Örnek ✓
#     Metin: microsoft japan to give away over one million xp sp2 cds tokyo microsoft corps japanese arm will beg...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %99.5
# ------------------------------------------------------------
#
# 40. Örnek ✓
#     Metin: sharon cautious on reopening talks the israeli prime minister ariel sharon yesterday said the death ...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 41. Örnek ✓
#     Metin: thais 39bomb 39 south with paper birds on muslim south around 50 thai air force planes quotbombed qu...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 42. Örnek ✓
#     Metin: deacons defeat friars justin gray leads wake forest with 21 points despite suffering a gashed face a...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %99.7
# ------------------------------------------------------------
#
# 43. Örnek ✓
#     Metin: screensaver strikes back at spammers new software allows recipients of spam to band together to targ...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 44. Örnek ✓
#     Metin: ramirez should be taking it to heart when it comes down to this when its worse than you could have p...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %95.3
# ------------------------------------------------------------
#
# 45. Örnek ✗
#     Metin: some people not eligible to get in on google ipo google has billed its ipo as a way for everyday peo...
#     Gerçek: Science/Technology (3)
#     Tahmin: Business (2)
#     Güven: %95.3
# ------------------------------------------------------------
#
# 46. Örnek ✓
#     Metin: one assist goal for hometown star stockholm sweden first peter forsberg watched as his retired jerse...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 47. Örnek ✓
#     Metin: crunch time for biotech companies washington area biotech companies will face pivotal moments this y...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %95.7
# ------------------------------------------------------------
#
# 48. Örnek ✓
#     Metin: report amount of fineparticle pollution drops significantly los angeles concentrations of one of the...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %97.3
# ------------------------------------------------------------
#
# 49. Örnek ✓
#     Metin: maker of twinkies goes into bankruptcy onge interstate bakeries corp has filed for bankruptcy a casu...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 50. Örnek ✓
#     Metin: court wont halt arch coals triton bid reuters reuters a us appeals court ruled on fridaythat arch co...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 51. Örnek ✓
#     Metin: pakistan ups security shi 39ites mourn bomb victims pakistan beefed up security saturday as minority...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 52. Örnek ✓
#     Metin: callender wins job as starter frustration set in quickly for andre callender he had already waited a...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 53. Örnek ✓
#     Metin: sa mercenaries plead not guilty sixtysix men accused of plotting a coup in equatorial guinea deny br...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %95.1
# ------------------------------------------------------------
#
# 54. Örnek ✓
#     Metin: rejuvenated real out to start scoring goals it has not gone unnoticed in spain that the four goals r...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 55. Örnek ✓
#     Metin: blair time for excuses on africa is over reuters reuters british prime ministertony blair is to say ...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 56. Örnek ✓
#     Metin: ibm launches topend power5 servers ibm has expanded the top end of its eserver range with three mult...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %99.8
# ------------------------------------------------------------
#
# 57. Örnek ✓
#     Metin: friday is all right for fighting tonight will be a busy one on the local fight scene with two cards ...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %99.5
# ------------------------------------------------------------
#
# 58. Örnek ✓
#     Metin: jpeg exploit could beat antivirus software most it managers won 39t question the importance of secur...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 59. Örnek ✓
#     Metin: ceo eisner to step down in sept 2006 wsj new york reuters michael eisner plans to step down as walt ...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 60. Örnek ✓
#     Metin: microsoft changes its tune on porting sp2 fixes microsoft watch redmond had told developers privatel...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 61. Örnek ✓
#     Metin: high court hears dispute over michigan interstate wine sales the supreme court is considering whethe...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %92.8
# ------------------------------------------------------------
#
# 62. Örnek ✓
#     Metin: putin says russia could be a yukos bidder president vladimir v putin said on friday that staterun co...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %96.9
# ------------------------------------------------------------
#
# 63. Örnek ✓
#     Metin: bekele and isinbayeva win athletes of the year titles in monaco montecarlo olympic champions kenenis...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %77.1
# ------------------------------------------------------------
#
# 64. Örnek ✓
#     Metin: oxford 18 cambridge 11 replacement winger ross lavery scored the decisive try just two minutes from ...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 65. Örnek ✓
#     Metin: beas new product chief regroups the first new face after a company shakeup says bea products will us...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %90.9
# ------------------------------------------------------------
#
# 66. Örnek ✓
#     Metin: us says no plans to sign new climate change pacts reuters reuters the united states considered anenv...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %99.4
# ------------------------------------------------------------
#
# 67. Örnek ✓
#     Metin: the sims 2 demon stone the number devil getting a life gets a lot more complicated in this sequel to...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %98.8
# ------------------------------------------------------------
#
# 68. Örnek ✓
#     Metin: elements of web hosting elements of web hostingwhen you first start out trying to get a site on the ...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 69. Örnek ✓
#     Metin: hezbollah plane flies over israel lebanon 39s guerrilla organization hezbollah announced sunday it h...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %99.3
# ------------------------------------------------------------
#
# 70. Örnek ✓
#     Metin: swimming phelps wins gold pulls out of relay athens reuters michael phelps who has won five gold med...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %98.8
# ------------------------------------------------------------
#
# 71. Örnek ✓
#     Metin: servicesector revenues rise in q2 revenues in key sectors of the us services industry grew in the se...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %98.8
# ------------------------------------------------------------
#
# 72. Örnek ✓
#     Metin: nike cofounder stepping down president effective december 28 after more than a yearlong search knigh...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %92.5
# ------------------------------------------------------------
#
# 73. Örnek ✓
#     Metin: this just in sprint is stupid found this via boingboing this morningthe new treo 650 is out today an...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %66.4
# ------------------------------------------------------------
#
# 74. Örnek ✓
#     Metin: kiwi firms ditch explorer for firefox aoraki mt cook ski planes and new zealand tourism online are t...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %99.5
# ------------------------------------------------------------
#
# 75. Örnek ✗
#     Metin: google 39s new pc search tool poses risks new york oct 18 2004 people who use public or workplace co...
#     Gerçek: Business (2)
#     Tahmin: Science/Technology (3)
#     Güven: %85.2
# ------------------------------------------------------------
#
# 76. Örnek ✓
#     Metin: youkilis mccarty placed on 15day disabled list boston it was another busy day on the medical front f...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 77. Örnek ✓
#     Metin: indycar champ kanaan finishes second and every lap fort worth texas helio castroneves had a great re...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %97.4
# ------------------------------------------------------------
#
# 78. Örnek ✓
#     Metin: business fiat talks tough ahead of key gm meeting quotthere is a very good argument to say that the ...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %99.5
# ------------------------------------------------------------
#
# 79. Örnek ✓
#     Metin: indian state rolls out wireless broadband government in south indian state of kerala sets up wireles...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %92.1
# ------------------------------------------------------------
#
# 80. Örnek ✓
#     Metin: nasa delays flight of x43a scramjet to attempt mach 10 los angeles nasa will try again today to fly ...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 81. Örnek ✓
#     Metin: tigers celebrating after beavers don 39t get their kicks freshman alexis serna is down on the field ...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 82. Örnek ✗
#     Metin: at last success on the road for lions the detroit lions went three full seasons without winning an a...
#     Gerçek: World News (0)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 83. Örnek ✓
#     Metin: angels ascend to firstplace tie with as ap ap for the first time in over three months the angels are...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 84. Örnek ✓
#     Metin: late rally sees wall street end week on a positive note us bluechips recovered from an early fall to...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %78.7
# ------------------------------------------------------------
#
# 85. Örnek ✓
#     Metin: red sox spread good feeling across nation ap ap it was a pinchme morning did the boston red sox real...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 86. Örnek ✓
#     Metin: ipod helps lift apples fourthquarter profit the ipod helped apples profit get up and dance apple com...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %98.6
# ------------------------------------------------------------
#
# 87. Örnek ✓
#     Metin: boston secures spot the red sox clinch a second straight trip to the playoffs topping tampa bay 73 m...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %97.2
# ------------------------------------------------------------
#
# 88. Örnek ✓
#     Metin: federated department stores posts profit new york reuters federated department stores inc lta hrefht...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 89. Örnek ✓
#     Metin: eu set to launch transit camps eu ministers agree to set up five pilot reception centres in africa t...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %93.6
# ------------------------------------------------------------
#
# 90. Örnek ✓
#     Metin: california employee pension fund tenders peoplesoft shares to ltbgtltbgt november 19 2004 idg news s...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %98.6
# ------------------------------------------------------------
#
# 91. Örnek ✓
#     Metin: lights camera beckham england 39s most celebrated soccer player david beckham has announced that he ...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 92. Örnek ✓
#     Metin: 46 killed 270 injured in iraqi violence baghdad sept 8 nnn bloody clashes on tuesday between us forc...
#     Gerçek: World News (0)
#     Tahmin: World News (0)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 93. Örnek ✓
#     Metin: hurricanes unrest in nigeria feed supply concerns san francisco cbsmw fueled by new supply worries i...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %99.7
# ------------------------------------------------------------
#
# 94. Örnek ✓
#     Metin: symantec to offer webbased norton antivirus console the web console to be made available specificall...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %99.9
# ------------------------------------------------------------
#
# 95. Örnek ✓
#     Metin: a serving of football efl style cant wait to see the super bowl champion new england patriots look t...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 96. Örnek ✓
#     Metin: cablevision narrows loss on revenue surge cablevision systems corp on tuesday said it narrowed its t...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %93.4
# ------------------------------------------------------------
#
# 97. Örnek ✓
#     Metin: water and robots on mars chosen as tops in 2004 science it 39s the discovery by two mars rovers that...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %100.0
# ------------------------------------------------------------
#
# 98. Örnek ✓
#     Metin: apple unveils super thin imac in paris afp afp apple computers launched the newest version of its im...
#     Gerçek: Science/Technology (3)
#     Tahmin: Science/Technology (3)
#     Güven: %97.9
# ------------------------------------------------------------
#
# 99. Örnek ✓
#     Metin: signing of teenage racer raises questions ap ap next october chase austin will finally be old enough...
#     Gerçek: Sports (1)
#     Tahmin: Sports (1)
#     Güven: %99.6
# ------------------------------------------------------------
#
# 100. Örnek ✓
#     Metin: stocks finish up apple provides a lift new york reuters us stocks rose on monday as a higher price t...
#     Gerçek: Business (2)
#     Tahmin: Business (2)
#     Güven: %99.6
# ------------------------------------------------------------
#
# Rastgele 100 örnekteki doğruluk: %94.0 (94/100)

# %% [markdown]
# ## 4. Manuel Test - Kendi Metninizi Test Edin
#
# Bu bölümde kendi yazdığınız metinleri test edebilirsiniz. Aşağıdaki hücreyi düzenleyerek istediğiniz metni ve beklenen kategoriyi belirleyebilirsiniz.

# %%
# MANUEL TEST - KENDİ METNİNİZİ BURAYA YAZIN
print("="*60)
print("MANUEL METİN TESTİ")
print("="*60)

# BURASI SİZİN DÜZENLEYECEĞİNİZ BÖLÜM
my_text = "Apple reported record quarterly earnings beating analyst expectations"
my_expected_category = 3 -1

category_names = [
    "World", "Sports", "Business", "Science/Technology"
]

def predict_text(text):
    cleaned = clean_text(text)
    seq = tokenizer.texts_to_sequences([cleaned])
    padded = pad_sequences(seq, maxlen=model_config["max_sequence_length"], padding='post', truncating='post')
    proba = rnn_model.predict(padded)
    pred = np.argmax(proba, axis=1)[0]
    return pred, proba[0]

if my_text and my_text.strip():
    pred_idx, proba = predict_text(my_text)
    print(f"Test Metni: {my_text}")
    print(f"Beklenen Kategori: {category_names[my_expected_category]}")
    print(f"Tahmin Edilen Kategori: {category_names[pred_idx]}")
    print(f"Tahmin Doğru mu?: {'EVET' if pred_idx == my_expected_category else 'HAYIR'}")
    print(f"Kategori Olasılıkları: {np.round(proba, 3)}")
else:
    print("Lütfen 'my_text' değişkenini yukarıda düzenleyin!")

# Örnek testler (isteğe bağlı)
sample_tests = [
    ("Manchester United won the Champions League final against Real Madrid", 1),  # Sports
    ("NASA successfully landed a rover on Mars surface", 3),  # Science/Technology
    ("European Union announces new trade sanctions against Russia", 0),  # World
    ("Tesla stock price surged after strong delivery numbers", 2),  # Business
    ("Scientists discovered a new species of dinosaur in Argentina", 3),  # Science/Technology
    ("A new method discovered", 3),  # Business
]

print("\nÖRNEK TESTLER")
for i, (sample_text, expected_cat) in enumerate(sample_tests[:6], 1):
    pred_idx, _ = predict_text(sample_text)
    print(f"{i}. [{category_names[expected_cat]}] {sample_text[:60]}...")
    print(f"   Tahmin: {category_names[pred_idx]} | Doğru mu?: {'EVET' if pred_idx == expected_cat else 'HAYIR'}")
# Out:
# ============================================================
# MANUEL METİN TESTİ
# ============================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Test Metni: Apple reported record quarterly earnings beating analyst expectations
# Beklenen Kategori: Business
# Tahmin Edilen Kategori: Science/Technology
# Tahmin Doğru mu?: HAYIR
# Kategori Olasılıkları: [0.   0.   0.43 0.57]
#
# ÖRNEK TESTLER
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1. [Sports] Manchester United won the Champions League final against Rea...
#    Tahmin: Sports | Doğru mu?: EVET
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2. [Science/Technology] NASA successfully landed a rover on Mars surface...
#    Tahmin: Science/Technology | Doğru mu?: EVET
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 3. [World] European Union announces new trade sanctions against Russia...
#    Tahmin: Business | Doğru mu?: HAYIR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4. [Business] Tesla stock price surged after strong delivery numbers...
#    Tahmin: Science/Technology | Doğru mu?: HAYIR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 5. [Science/Technology] Scientists discovered a new species of dinosaur in Argentina...
#    Tahmin: Science/Technology | Doğru mu?: EVET
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 6. [Science/Technology] A new method discovered...
#    Tahmin: Science/Technology | Doğru mu?: EVET

# %% [markdown]
# ## 5. Detaylı Analiz - Comprehensive Model Evaluation
#
# Bu bölümde tüm modellerin performansını detaylı şekilde analiz ediyoruz:
#
# ### Analizler:
# - **Confusion Matrix**: Her model için karışıklık matrisi
# - **Kategori Bazında Doğruluk**: Hangi kategoride hangi model en başarılı
# - **Model Hızları**: Prediction süreleri karşılaştırması
# - **En İyi Model Seçimi**: Farklı kriterler için öneriler
# - **Detaylı Performans Metrikleri**: Precision, Recall, F1-Score

# %%
# DETAYLI ANALİZ - SADECE RNN MODELİ İÇİN

import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

if not test_texts or not test_labels:
    print("Test verileri bulunamadı! Önce test hücresini çalıştırın.")
else:
    print("="*60)
    print("DETAYLI ANALİZ - RNN MODELİ")
    print("="*60)
    
    # Toplu tahmin
    sequences = tokenizer.texts_to_sequences(test_texts)
    X = pad_sequences(sequences, maxlen=model_config["max_sequence_length"], padding='post', truncating='post')
    y_true = np.array(test_labels)
    y_pred_proba = rnn_model.predict(X, verbose=0)
    y_pred = np.argmax(y_pred_proba, axis=1)

    # Genel performans
    acc = accuracy_score(y_true, y_pred)
    print(f"Genel Accuracy: {acc:.4f}")
    print("\nClassification Report:\n")
    print(classification_report(
        y_true, y_pred, target_names=[
            "World", "Sports", "Business", "Science/Technology"
        ]
    ))

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    category_names = [
        "World", "Sports", "Business", "Science/Technology"
    ]
    present_labels = sorted(list(set(y_true)))
    present_names = [category_names[i] for i in present_labels]
    print("\nConfusion Matrix:")
    cm_df = pd.DataFrame(cm, index=present_names, columns=present_names)
    print(cm_df)

    # Kategori bazında doğruluk
    print("\nKategori Bazında Doğruluk:")
    for idx, name in zip(present_labels, present_names):
        mask = y_true == idx
        cat_acc = accuracy_score(y_true[mask], y_pred[mask])
        print(f"{name}: {cat_acc:.3f} ({mask.sum()} sample)")
# Out:
# ============================================================
# DETAYLI ANALİZ - RNN MODELİ
# ============================================================
# Genel Accuracy: 0.9287
#
# Classification Report:
#
#                     precision    recall  f1-score   support
#
#              World       0.95      0.92      0.93      1900
#             Sports       0.97      0.98      0.98      1900
#           Business       0.90      0.89      0.90      1900
# Science/Technology       0.89      0.92      0.91      1900
#
#           accuracy                           0.93      7600
#          macro avg       0.93      0.93      0.93      7600
#       weighted avg       0.93      0.93      0.93      7600
#
#
# Confusion Matrix:
#                     World  Sports  Business  Science/Technology
# World                1742      37        67                  54
# Sports                 14    1864        13                   9
# Business               40      12      1700                 148
# Science/Technology     35       9       104                1752
#
# Kategori Bazında Doğruluk:
# World: 0.917 (1900 sample)
# Sports: 0.981 (1900 sample)
# Business: 0.895 (1900 sample)
# Science/Technology: 0.922 (1900 sample)
